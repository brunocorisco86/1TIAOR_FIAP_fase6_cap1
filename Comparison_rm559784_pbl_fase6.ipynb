# %% [markdown]
# <a href="https://colab.research.google.com/github/brunocorisco86/1TIAOR_FIAP_fase6_cap1/blob/main/Comparison_rm559784_pbl_fase6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
